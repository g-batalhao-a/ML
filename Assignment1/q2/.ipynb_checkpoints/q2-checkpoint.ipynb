# %%
# Question 2: Logistic Regression
# !pip install -U pandas
# !pip install -U numpy
# !pip install -U plotly==5.10.0

import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

dataset = np.genfromtxt('../data/q2/q2test.csv', delimiter=',')

x1 = dataset[1:, 0].reshape(-1,1)
x2 = dataset[1:, 1].reshape(-1,1)
y_test = dataset[1:, 2].reshape(-1,1)
x0 = np.ones((x1.shape))
x_test = np.append(x0, x1, axis=1)
x_test = np.append(x_test, x2, axis=1)
n = x_test.shape[0]
# Out:
# Requirement already satisfied: pandas in c:\users\gbata\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gbata\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\gbata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\gbata\anaconda3\lib\site-packages (from pandas) (1.23.2)
# Requirement already satisfied: six>=1.5 in c:\users\gbata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\gbata\anaconda3\lib\site-packages (1.23.2)
# Requirement already satisfied: plotly==5.10.0 in c:\users\gbata\anaconda3\lib\site-packages (5.10.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\gbata\anaconda3\lib\site-packages (from plotly==5.10.0) (8.0.1)
# C:\Users\gbata\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Question 2.a - Sample million of points

#Data points given
data_points= 1000000
#Intercept term
x0 = np.ones((data_points,1)) 

#Samples
x1 = np.random.normal(3, 2, data_points).reshape(-1,1)
x2 = np.random.normal(-1, 2, data_points).reshape(-1,1)

#Create matrix
x = np.append(x0,x1,axis=1)
x = np.append(x, x2, axis=1)

#Sample epsilon error
eps = np.random.normal(0, np.sqrt(2), data_points).reshape(-1,1)

theta = np.array([[3], [1], [2]])

#Generate the value of Y (given X, parameterized by given Theta)
y = np.dot(x,theta) + eps

#Shuffle data
temp = np.append(x, y, axis=1)
np.random.shuffle(temp)

x = temp[:,0:3]
y = temp[:,-1:]

# %%
#Question 2.b - Apply Stochastic gradient descent
import time

theta = np.zeros((3,1))
alpha = 0.001  
b_size = np.array([1, 100, 10000, 1000000])

# Prediction function: h(θ) = x^Tθ 
def predict(x, theta):
    return x.dot(theta)

# Cost function: J(θ) = 1/2m * Σ(y-h(θ))^2
def cost(x,y,theta, m):
    return (1/(2*m)) * np.sum((y - predict(x,theta))**2)

cost_0 = cost(x, y, theta, data_points)
print("Initial Cost value for the hypothesis with zero parameters={}".format(cost_0))


def cost_grd(x, y, theta, m):
    return (1/m) * (np.zeros((3,1))+  x.T.dot(x.dot(theta)-y))


# Stochastic descent function
def stochastic_gradient_descent(x, y, theta, alpha, r, threshold=10e-7):
    
    start = time.time()

    i=0
    c=0.0
    theta_hist = theta
    c_avg = np.array([cost(x[0], y[0], theta, 1)])

    while(True):
        i+=1
        count = 0
        c_init = cost(x, y,theta, data_points)
        for b in mini_batch:
            x_b = b[0]
            y_b = b[1]
            c += cost(x_b, y_b, theta, r)
            
            check = 10000 if r==1 else 100 if r==100 else 10 if r==10000 else 1
            if(count%check == 0 and count!=0):
                c /= check
                print("Current average cost = {}".format(c)) 
                c_avg = np.append(c_avg, c)
                c=0.0
            theta -= alpha * cost_grd(x_b, y_b, theta, r)
            theta_hist = np.append(theta_hist,theta,axis=1)
            count +=1
        c_final = cost(x, y, theta, data_points)
        if (abs(c_final - c_init) < threshold):
            print(c_final, c_init, c_final-c_init)
            break
    
    end = time.time()
        

    return theta, c_final, theta_hist, i, end-start



values = []
for r in b_size:
    #number of batches (sub batches stored in an array mini_batch)
    mini_batch = [(x[i:i+r,:], y[i:i+r]) for i in range(0, data_points, r)]
    theta, c_final, theta_hist, iterations, time = stochastic_gradient_descent(x, y, theta, alpha, r)
    print(f'Cost of the model is {c_final} with {iterations} iterations and {time} s')
    values.append((theta, c_final, theta_hist, iterations, time, r))



print(values)
# Out:
# Initial Cost value for the hypothesis with zero parameters=19.020785601901146
# Current average cost = 1.372083184514768
# Current average cost = 0.9971271572285783
# Current average cost = 1.0095941006969333
# Current average cost = 1.0144651857510463
# Current average cost = 1.000664150183633
# Current average cost = 1.0106299597872959
# Current average cost = 1.0011860709458558
# Current average cost = 1.0325036697333665
# Current average cost = 1.0212285324151797
# Current average cost = 1.032240705586853
# Current average cost = 1.0501749236605922
# Current average cost = 0.9844985496943549
# Current average cost = 1.0082831143135607
# Current average cost = 1.0294489295807268
# Current average cost = 1.010232932123918
# Current average cost = 1.0345845142437773
# Current average cost = 1.00874459457434
# Current average cost = 0.9915423977850225
# Current average cost = 1.0225660452065404
# Current average cost = 1.0299426408253858
# Current average cost = 1.017216036711031
# Current average cost = 1.0045087665310772
# Current average cost = 1.00541409320417
# Current average cost = 0.9973147349800465
# Current average cost = 1.0011022702559016
# Current average cost = 1.0298181714962626
# Current average cost = 1.0060337161490458
# Current average cost = 0.9987596815203109
# Current average cost = 1.0161172389616882
# Current average cost = 1.0069779850873108
# Current average cost = 0.9859595200218051
# Current average cost = 1.0229885840584232
# Current average cost = 1.0010078639870539
# Current average cost = 1.0338356910427282
# Current average cost = 1.0049185120349204
# Current average cost = 1.003333751894225
# Current average cost = 1.0068764595095823
# Current average cost = 0.9966018438326124
# Current average cost = 1.0192315226191242
# Current average cost = 0.9911056854769864
# Current average cost = 1.0071631960758187
# Current average cost = 1.0208069255472312
# Current average cost = 1.0247879618000577
# Current average cost = 0.9995122433062635
# Current average cost = 1.004319105938542
# Current average cost = 1.0023316674393603
# Current average cost = 1.0048752920956068
# Current average cost = 1.0113248183968389
# Current average cost = 1.0088668297662489
# Current average cost = 0.9992814360073171
# Current average cost = 1.0041222956639377
# Current average cost = 1.003453083303379
# Current average cost = 0.9859716289357914
# Current average cost = 0.9876029446968829
# Current average cost = 1.01545221506989
# Current average cost = 1.0032209333792546
# Current average cost = 1.0104751019068734
# Current average cost = 1.0348380092952048
# Current average cost = 0.9957239487292623
# Current average cost = 1.012949970357854
# Current average cost = 1.0178373085798698
# Current average cost = 1.006635521918894
# Current average cost = 1.0087231907356784
# Current average cost = 0.9802080497604293
# Current average cost = 1.0286846169103878
# Current average cost = 1.001019880870609
# Current average cost = 0.989970808549416
# Current average cost = 0.9999507219505833
# Current average cost = 1.0012029215373945
# Current average cost = 1.0112373714612455
# Current average cost = 0.9884140184157817
# Current average cost = 1.0207457139377956
# Current average cost = 1.020290389297174
# Current average cost = 0.9830958635730392
# Current average cost = 1.0189661419900586
# Current average cost = 1.001470638669574
# Current average cost = 1.0085511229620834
# Current average cost = 1.0074099035204627
# Current average cost = 1.001404200045717
# Current average cost = 1.0070600044450302
# Current average cost = 0.9988293920480448
# Current average cost = 1.0064510024587352
# Current average cost = 1.0132327830102636
# Current average cost = 1.0145412723921459
# Current average cost = 1.0404290180122422
# Current average cost = 0.9885513856065284
# Current average cost = 1.006827609505791
# Current average cost = 1.0182722964449817
# Current average cost = 1.0011886854165917
# Current average cost = 1.0066957218903927
# Current average cost = 1.0153557398507769
# Current average cost = 1.0278991285374193
# Current average cost = 1.0106873980018822
# Current average cost = 1.0299931754538458
# Current average cost = 1.0105126219053286
# Current average cost = 1.0291348902625697
# Current average cost = 1.019545903907076
# Current average cost = 1.0252737236719347

# %%
err_og = cost(x_test, y_test, np.array([[3],[1],[2]]), n)
print("The Test error on Original Hypothesis with theta = 0 is = {}".format(err_og))

for value in values:
    (theta, c_final, theta_hist, iterations, time, r) = value
    err_new = cost(x_test, y_test, theta, n)
    print("The Test error on Learned Hypothesis = {}, , for r = {}".format(err_new))

    print("The difference in the test error of original and learned hypothesis is = {}, for r = {}".format(err_new-err_og))

# %%
from matplotlib.animation import FuncAnimation

for value in values:
    
    #Plot Graph
    fig = plt.figure(figsize=(15,10))
    ax = fig.add_subplot(111, projection='3d')
    ax.view_init(45, 20)
    
    (theta, c_final, theta_hist, iterations, time, r) = value
    t = theta_hist.T[0:40000:5,:] if r==1 else theta_hist.T[0::15,:] if (r==100) or (r==10000)  else theta_hist.T[0::30,:] 
    step = 1000 if r==1 else 20 if (r==100) or (r==10000)  else 10
    sc = ax.scatter([], [], [], marker='o', c='k')
    x_, y_, z_ = [], [], []

    def animate(i):
        x_.append(t[i,0])
        y_.append(t[i,1])
        z_.append(t[i,2])
        sc._offsets3d = (x_, y_, z_)
        return sc

    anim = FuncAnimation(fig, animate, frames=np.arange(0, t.shape[0]), interval=200, repeat_delay=3000, blit=False)
    anim.save('q1_'+str(r)+'c.gif', writer='pillow')
    plt.show()
